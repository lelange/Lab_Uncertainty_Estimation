# %%
import json

# %%
# nnUNet_evaluate_folder -ref /home/annalena/Seminar_Medical_Image_Analysis/code/data/nnUNet_raw_data_base/nnUNet_raw_data/Task679_mnm/labelsTr/ -pred /home/annalena/Seminar_Medical_Image_Analysis/code/nnUNet_trained_models/nnUNet/2d/Task500_ACDC/nnUNetTrainerV2_SGD_fixedSchedule_Zhao2022__nnUNetPlansv2.1_bs20/prediction_Task679_mnm/model_ep_392 -l 1 2 3
path = "/home/annalena/Seminar_Medical_Image_Analysis/code/nnUNet_trained_models/nnUNet/2d/Task500_ACDC/nnUNetTrainerV2_SGD_fixedSchedule_Zhao2022__nnUNetPlansv2.1_bs20/prediction_Task679_mnm/model_ep_392/summary.json"
with open(path, 'r') as f:
    data = json.load(f)

# %%
print(data.keys())
print(data['results'].keys())
# Out:
# dict_keys(['author', 'description', 'id', 'name', 'results', 'task', 'timestamp'])
# dict_keys(['all', 'mean'])

# %%
#data['results']['mean']

# %%
#data['results']['all'][0]

# %%
#data['results']['all'][0]

# %%
path = "/home/annalena/Seminar_Medical_Image_Analysis/code/nnUNet_trained_models/nnUNet/2d/Task500_ACDC/nnUNetTrainerV2_SGD_fixedSchedule_Zhao2022__nnUNetPlansv2.1_bs20/prediction_Task679_mnm/model_best/summary.json"
with open(path, 'r') as f:
    data = json.load(f)
print(data.keys())
print(data['results'].keys())
# Out:
# dict_keys(['author', 'description', 'id', 'name', 'results', 'task', 'timestamp'])
# dict_keys(['all', 'mean'])

# %%
data['results']['mean']
# Out:
# {'1': {'Accuracy': 0.9805753357295691,
#   'Dice': 0.00028986565178296163,
#   'False Discovery Rate': 0.9995977851869686,
#   'False Negative Rate': 0.999758699795384,
#   'False Omission Rate': 0.010572952499099796,
#   'False Positive Rate': 0.009097855768254545,
#   'Jaccard': 0.0001476106001820822,
#   'Negative Predictive Value': 0.9894270475009002,
#   'Precision': 0.000402214813031331,
#   'Recall': 0.0002413002046159267,
#   'Total Positives Reference': 7352.8966666666665,
#   'Total Positives Test': 6545.8533333333335,
#   'True Negative Rate': 0.9909021442317455},
#  '2': {'Accuracy': 0.9965323583326899,
#   'Dice': 0.8319655506107111,
#   'False Discovery Rate': 0.1589133597546374,
#   'False Negative Rate': 0.16888116271785727,
#   'False Omission Rate': 0.0018466751631339392,
#   'False Positive Rate': 0.001663086607810007,
#   'Jaccard': 0.7157210719231095,
#   'Negative Predictive Value': 0.9981533248368661,
#   'Precision': 0.8410866402453626,
# ...

# %%
import pickle

with open("/home/annalena/Seminar_Medical_Image_Analysis/code/nnUNet_trained_models/nnUNet/2d/Task500_ACDC/nnUNetTrainerV2_SGD_fixedSchedule_Zhao2022__nnUNetPlansv2.1_bs20/plans.pkl", "rb") as f:
    data = pickle.load(f)

# %%
data
# Out:
# {'num_stages': 1,
#  'num_modalities': 1,
#  'modalities': {0: 'MRI'},
#  'normalization_schemes': OrderedDict([(0, 'nonCT')]),
#  'dataset_properties': {'all_sizes': [(10, 256, 216),
#    (10, 256, 216),
#    (10, 256, 231),
#    (10, 256, 231),
#    (10, 255, 256),
#    (10, 255, 256),
#    (10, 256, 232),
#    (10, 256, 232),
#    (10, 216, 255),
#    (10, 216, 255),
#    (11, 256, 231),
#    (11, 256, 231),
#    (10, 223, 222),
#    (10, 223, 222),
#    (10, 256, 199),
#    (10, 256, 199),
#    (10, 256, 208),
#    (10, 256, 208),
#    (10, 256, 208),
#    (10, 256, 208),
#    (9, 256, 216),
#    (9, 256, 216),
#    (10, 256, 184),
#    (10, 256, 184),
#    (10, 256, 216),
#    (10, 256, 216),
#    (10, 216, 256),
#    (10, 216, 256),
#    (9, 216, 256),
#    (9, 216, 256),
#    (10, 256, 192),
#    (10, 256, 192),
#    (9, 256, 216),
#    (9, 256, 216),
#    (8, 256, 216),
#    (8, 256, 216),
#    (11, 256, 216),
#    (11, 256, 216),
#    (8, 256, 208),
#    (8, 256, 208),
# ...

# %%
import json
home = "/home/annalena/Seminar_Medical_Image_Analysis/code/"
path = "nnUNet_trained_models/nnUNet/2d/Task500_ACDC/nnUNetTrainerV2_SGD_fixedSchedule_Zhao2022__nnUNetPlansv2.1_bs20/fold_0/postprocessing.json"
path2 = "nnUNet_trained_models/nnUNet/2d/Task500_ACDC/nnUNetTrainerV2_SGD_fixedSchedule_Zhao2022__nnUNetPlansv2.1_bs20/fold_0/validation_raw/summary.json"
with open(home + path2, 'r') as f:
    data = json.load(f)

# %%
data
# Out:
# {'author': 'Fabian',
#  'description': '',
#  'id': '5b62b3d624fa',
#  'name': 'nnUNetTrainerV2_SGD_fixedSchedule_Zhao2022 val tiled True',
#  'results': {'all': [{'0': {'Accuracy': 0.9975341031543887,
#      'Dice': 0.9987177476931796,
#      'False Discovery Rate': 0.0015278206593182242,
#      'False Negative Rate': 0.0010365631324269486,
#      'False Omission Rate': 0.026075462629175677,
#      'False Positive Rate': 0.037982195845697286,
#      'Jaccard': 0.9974387795172314,
#      'Negative Predictive Value': 0.9739245373708243,
#      'Precision': 0.9984721793406818,
#      'Recall': 0.998963436867573,
#      'Total Positives Reference': 628037,
#      'Total Positives Test': 628346,
#      'True Negative Rate': 0.9620178041543027},
#     '1': {'Accuracy': 0.9983989273119123,
#      'Dice': 0.9355911330049261,
#      'False Discovery Rate': 0.04259609325771896,
#      'False Negative Rate': 0.08524984948826009,
#      'False Omission Rate': 0.0010970332069472572,
# ...
